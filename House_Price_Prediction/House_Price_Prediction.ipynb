# %%
import pandas as pd
df = pd.read_csv("house_price_large_dataset.csv")
print(df.head(2))
# Out:
#    Area_sqft  Bedrooms  Bathrooms  Floors  House_Age  Distance_from_City_km  \
# 0       1260         2          4       3         40              18.009891
# 1       4172         6          3       1         18              19.152049
#
#       Price
# 0   6413339
# 1  15628370

# %%
x = df.drop("Price" , axis = 1)
y = df['Price']

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 40)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
print(y_pred)
# Out:
# [ 8641714.10085186 14720331.9921876   8381758.18138498 ...
#   6490562.10688191  7417250.6469473   6058605.05878541]

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test , y_pred)
plt.plot(y_test , y_test , color = 'red')
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
# Out:
# Text(0, 0.5, 'Predicted Price')
